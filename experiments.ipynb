# %% [markdown]
# # Importing the Experiment Object

# %%
from experiment import Experiment

# %% [markdown]
# # Roulette Wheel

# %%
experiment = Experiment(method="roulette")
experiment.print_configuration()
experiment.start(report_dir="reports")
# Out:
# ---------------------------------------
# Experiment with Method: roulette
# ---------------------------------------
# Genetic Algorithm Params:
# Mutation Rate: 0.1
# Population Size: 75
# Epochs: 50
# ---------------------------------------
# Experiment configurations:
# Iterations: 5
# n: 10, m: 1000
# n: 10, m: 2000
# n: 10, m: 3000
# n: 10, m: 4000
# n: 10, m: 5000
# n: 20, m: 1000
# n: 20, m: 2000
# n: 20, m: 3000
# n: 20, m: 4000
# n: 20, m: 5000
# n: 30, m: 1000
# n: 30, m: 2000
# n: 30, m: 3000
# n: 30, m: 4000
# n: 30, m: 5000
# ---------------------------------------
# Model initialized.
# ---------------------------------------
# Starting the experiments...
# ---------------------------------------
# Setup: 1 expend 0.34536853333333334 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 743 745.6 748 1.62 0.07 0.35
#
# Setup: 2 expend 0.7089274166666667 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 743 745.6 748 1.62 0.07 0.35
# ...

# %% [markdown]
# # Stochastic Universal Sampling

# %%
experiment = Experiment(method="sus")
experiment.print_configuration()
experiment.start(report_dir="reports")
# Out:
# ---------------------------------------
# Experiment with Method: sus
# ---------------------------------------
# Genetic Algorithm Params:
# Mutation Rate: 0.1
# Population Size: 75
# Epochs: 50
# ---------------------------------------
# Experiment configurations:
# Iterations: 5
# n: 10, m: 1000
# n: 10, m: 2000
# n: 10, m: 3000
# n: 10, m: 4000
# n: 10, m: 5000
# n: 20, m: 1000
# n: 20, m: 2000
# n: 20, m: 3000
# n: 20, m: 4000
# n: 20, m: 5000
# n: 30, m: 1000
# n: 30, m: 2000
# n: 30, m: 3000
# n: 30, m: 4000
# n: 30, m: 5000
# ---------------------------------------
# Model initialized.
# ---------------------------------------
# Starting the experiments...
# ---------------------------------------
# Setup: 1 expend 0.33518298333333335 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 748 750.0 754 2.19 0.07 0.27
#
# Setup: 2 expend 0.6578497833333333 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 748 750.0 754 2.19 0.07 0.27
# ...

# %% [markdown]
# # Tournament Selection

# %%
experiment = Experiment(method="tournament")
experiment.print_configuration()
experiment.start(report_dir="reports")
# Out:
# ---------------------------------------
# Experiment with Method: tournament
# ---------------------------------------
# Genetic Algorithm Params:
# Mutation Rate: 0.1
# Population Size: 75
# Epochs: 50
# ---------------------------------------
# Experiment configurations:
# Iterations: 5
# n: 10, m: 1000
# n: 10, m: 2000
# n: 10, m: 3000
# n: 10, m: 4000
# n: 10, m: 5000
# n: 20, m: 1000
# n: 20, m: 2000
# n: 20, m: 3000
# n: 20, m: 4000
# n: 20, m: 5000
# n: 30, m: 1000
# n: 30, m: 2000
# n: 30, m: 3000
# n: 30, m: 4000
# n: 30, m: 5000
# ---------------------------------------
# Model initialized.
# ---------------------------------------
# Starting the experiments...
# ---------------------------------------
# Setup: 1 expend 0.32568923333333333 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 725 732.2 746 7.19 0.07 0.99
#
# Setup: 2 expend 0.64844965 minutes, report:
# n m Min Avg. Max Std. Time Mean
# 10 1000 725 732.2 746 7.19 0.07 0.99
# ...
